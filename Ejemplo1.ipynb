# %% [markdown]
# Ejemplo 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Spotify_Youtube.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %% [markdown]
# 1. Obtener data frame de youtube
# 2. Ordenarlos conforme la cantidad de like descendente
# 3. Graficar los primeros 10 artistas conforme a la cantidad de likes
# 4. Repetir proceso con spotify
# 5. Graficar a los mejores artistas conforme sus likes
# 6. Compararlo con spotify

# %% [markdown]
# 1

# %%
df_youtube = df[["Artist", "Url_youtube", "Title", "Likes"]]
df_youtube.head()
# Out:
#      Artist                                  Url_youtube  \
# 0  Gorillaz  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1  Gorillaz  https://www.youtube.com/watch?v=yYDmaexVHic
# 2  Gorillaz  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3  Gorillaz  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4  Gorillaz  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                Title      Likes
# 0         Gorillaz - Feel Good Inc. (Official Video)  6220896.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  1079128.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...   282142.0
# 3     Gorillaz - On Melancholy Hill (Official Video)  1788577.0
# 4         Gorillaz - Clint Eastwood (Official Video)  6197318.0

# %% [markdown]
# 2

# %%
df_youtube_sorted = df_youtube.sort_values(by="Likes", ascending=False)
df_youtube_sorted.head()
# Out:
#              Artist                                  Url_youtube  \
# 1147     Luis Fonsi  https://www.youtube.com/watch?v=kJQP7kiw5Fk
# 365    Daddy Yankee  https://www.youtube.com/watch?v=kJQP7kiw5Fk
# 14580  Charlie Puth  https://www.youtube.com/watch?v=RgKAFK5djSk
# 12469   Wiz Khalifa  https://www.youtube.com/watch?v=RgKAFK5djSk
# 14561           BTS  https://www.youtube.com/watch?v=gdZLi9oWNZg
#
#                                                    Title       Likes
# 1147             Luis Fonsi - Despacito ft. Daddy Yankee  50788652.0
# 365              Luis Fonsi - Despacito ft. Daddy Yankee  50788626.0
# 14580  Wiz Khalifa - See You Again ft. Charlie Puth [...  40147674.0
# 12469  Wiz Khalifa - See You Again ft. Charlie Puth [...  40147618.0
# 14561                 BTS (방탄소년단) 'Dynamite' Official MV  35892575.0

# %%
top_visits = df_youtube_sorted.head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x='Likes', y='Title', data=top_visits, palette='viridis')

plt.title("Top 10 canciones por likes")
plt.xlabel('Likes')
plt.ylabel('Title')
plt.show()
# Out:
# C:\Users\landm\AppData\Local\Temp\ipykernel_18632\1309326269.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Likes', y='Title', data=top_visits, palette='viridis')
# c:\Users\landm\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48169 (\N{HANGUL SYLLABLE BANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\landm\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 53444 (\N{HANGUL SYLLABLE TAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\landm\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
# ...

# %% [markdown]
# Suma de likes de artistas

# %%
top_visits_sum = df_youtube_sorted.groupby('Artist').sum().sort_values(by='Likes', ascending=False).head(10)
top_visits_sum.head(10)
# Out:
#                                                        Url_youtube  \
# Artist
# BTS              https://www.youtube.com/watch?v=gdZLi9oWNZghtt...
# BLACKPINK        https://www.youtube.com/watch?v=ioNng23DkIMhtt...
# Charlie Puth     https://www.youtube.com/watch?v=RgKAFK5djSkhtt...
# Ed Sheeran       https://www.youtube.com/watch?v=JGwWNGJdvx8htt...
# Justin Bieber    https://www.youtube.com/watch?v=kffacxfA7G4htt...
# Billie Eilish    https://www.youtube.com/watch?v=V1Pl8CzNzCwhtt...
# Imagine Dragons  https://www.youtube.com/watch?v=7wtfhZwyrcchtt...
# Alan Walker      https://www.youtube.com/watch?v=60ItHLz5WEAhtt...
# DJ Snake         https://www.youtube.com/watch?v=ixkoVwKQaJghtt...
# Luis Fonsi       https://www.youtube.com/watch?v=kJQP7kiw5Fkhtt...
#
#                                                              Title  \
# Artist
# BTS              BTS (방탄소년단) 'Dynamite' Official MVBTS (방탄소년단) ...
# BLACKPINK        BLACKPINK - 'How You Like That' M/VBLACKPINK -...
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Likes', y='Artist', data=top_visits_sum, palette='viridis')

plt.title("Top 10 canciones por likes")
plt.xlabel('Likes')
plt.ylabel('Artist')
plt.show()
# Out:
# C:\Users\landm\AppData\Local\Temp\ipykernel_18632\3579570508.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Likes', y='Artist', data=top_visits_sum, palette='viridis')

# %% [markdown]
# 3

# %% [markdown]
# 4

# %%
df_spotify = df[["Artist", "Url_spotify", "Track", "Energy"]]
df_spotify.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  Energy
# 0                                 Feel Good Inc.   0.705
# 1                                Rhinestone Eyes   0.703
# 2  New Gold (feat. Tame Impala and Bootie Brown)   0.923
# 3                             On Melancholy Hill   0.739
# 4                                 Clint Eastwood   0.694

# %%
df_spotify_sorted = df_spotify.sort_values(by="Energy", ascending=False)
df_spotify_sorted.head()
# Out:
#                    Artist                                        Url_spotify  \
# 20652      Sleepy Penguin  https://open.spotify.com/artist/32Rb6mS5HQKCu8...
# 20581  Rain Fruits Sounds  https://open.spotify.com/artist/5OQTGVAJnAH4u8...
# 20587  Rain Fruits Sounds  https://open.spotify.com/artist/5OQTGVAJnAH4u8...
# 20582  Rain Fruits Sounds  https://open.spotify.com/artist/5OQTGVAJnAH4u8...
# 20586  Rain Fruits Sounds  https://open.spotify.com/artist/5OQTGVAJnAH4u8...
#
#                                Track  Energy
# 20652          Gentle Piano Melodies     1.0
# 20581   Rain and Thunderstorm, Pt. 3     1.0
# 20587  Rain and Thunderstorm, Pt. 33     1.0
# 20582   Rain and Thunderstorm, Pt. 4     1.0
# 20586   Rain and Thunderstorm, Pt. 6     1.0

# %%
print(df_spotify_sorted.columns)
# Out:
# Index(['Artist', 'Url_spotify', 'Track', 'Energy'], dtype='object')

# %%
top_tracks = df_spotify_sorted.head(10)
plt.figure(figsize=(10,6))
sns.barplot(x='Energy', y='Track', data=top_tracks, palette='viridis')

plt.title('Top 10 canciones por energia')
plt.xlabel('Energy')
plt.ylabel('Track')
plt.show()
# Out:
# C:\Users\landm\AppData\Local\Temp\ipykernel_18632\1859711950.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Energy', y='Track', data=top_tracks, palette='viridis')

# %% [markdown]
# Suma de Energia de artistas

# %%
top_tracks_sum = df_spotify_sorted.groupby('Artist').sum().sort_values(by='Energy', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x='Energy', y='Artist', data=top_tracks_sum, palette='viridis')

plt.title("Top 10 canciones por Energia")
plt.xlabel('Likes')
plt.ylabel('Artist')
plt.show()
# Out:
# C:\Users\landm\AppData\Local\Temp\ipykernel_18632\2123322481.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Energy', y='Artist', data=top_tracks_sum, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Energy', y='Artist', data=top_tracks_sum, palette='viridis')

plt.title("Top 10 canciones por Energia")
plt.xlabel('Likes')
plt.ylabel('Artist')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x='Likes', y='Artist', data=top_visits_sum, palette='viridis')

plt.title("Top 10 canciones por likes")
plt.xlabel('Likes')
plt.ylabel('Artist')
plt.show()
# Out:
# C:\Users\landm\AppData\Local\Temp\ipykernel_18632\4288303934.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Energy', y='Artist', data=top_tracks_sum, palette='viridis')
# C:\Users\landm\AppData\Local\Temp\ipykernel_18632\4288303934.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Likes', y='Artist', data=top_visits_sum, palette='viridis')

# %% [markdown]
# Unir ambos en un solo DataFrame

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# %% [markdown]
# Primer gráfico (Spotify - Energía)

# %%
colors = sns.color_palette("coolwarm", len(top_tracks_sum))
sizes = top_tracks_sum["Energy"] * 100  # Ajustamos el tamaño de los círculos

sns.barplot(
    x=top_tracks_sum.index, y=top_tracks_sum["Energy"], palette=colors, alpha=0.7, ax=axes[0]
)

for i, energy in enumerate(top_tracks_sum["Energy"]):
    axes[0].scatter(i, energy, s=sizes[i], color=colors[i], edgecolors="black", alpha=0.8)

axes[0].set_ylabel("Nivel de Energía")
axes[0].set_xlabel("Artista")
axes[0].set_title("Top 10 Artistas con Mayor Energía en Spotify")
axes[0].set_xticklabels(top_tracks_sum.index, rotation=45, ha="right")
# Out:
# C:\Users\landm\AppData\Local\Temp\ipykernel_18632\711083690.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\landm\AppData\Local\Temp\ipykernel_18632\711083690.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   axes[0].scatter(i, energy, s=sizes[i], color=colors[i], edgecolors="black", alpha=0.8)
# C:\Users\landm\AppData\Local\Temp\ipykernel_18632\711083690.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(top_tracks_sum.index, rotation=45, ha="right")
# [Text(0, 0, 'Rain Fruits Sounds'),
# ...

# %% [markdown]
# Segundo gráfico (YouTube - Likes)

# %%
sns.barplot(
    x=top_visits_sum.index, y=top_visits_sum["Likes"], palette="rocket", ax=axes[1]
)

axes[1].set_ylabel("Número de Likes")
axes[1].set_xlabel("Artista")
axes[1].set_title("Top 10 Artistas con Más Likes en YouTube")
axes[1].set_xticklabels(top_visits_sum.index, rotation=45, ha="right")
# Out:
# C:\Users\landm\AppData\Local\Temp\ipykernel_18632\2253520356.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\landm\AppData\Local\Temp\ipykernel_18632\2253520356.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(top_visits_sum.index, rotation=45, ha="right")
# [Text(0, 0, 'BTS'),
#  Text(1, 0, 'BLACKPINK'),
#  Text(2, 0, 'Charlie Puth'),
#  Text(3, 0, 'Ed Sheeran'),
#  Text(4, 0, 'Justin Bieber'),
#  Text(5, 0, 'Billie Eilish'),
#  Text(6, 0, 'Imagine Dragons'),
#  Text(7, 0, 'Alan Walker'),
#  Text(8, 0, 'DJ Snake'),
#  Text(9, 0, 'Luis Fonsi')]

# %% [markdown]
# Ajustar el diseño y mostrar

# %%
plt.tight_layout()
plt.show()
